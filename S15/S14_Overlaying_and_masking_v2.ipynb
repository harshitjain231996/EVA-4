# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import numpy as np
from PIL import Image
import random
import copy
import PIL

# %%
# !mkdir Overlay2
# Out:
# mkdir: cannot create directory ‘Overlay2’: File exists

# %%
# %cd Overlay2
# !mkdir Fg-Bg
# !mkdir Fg-Bg-Mask
# Out:
# /content/Overlay2

# %%
# %cd ..
# Out:
# /content

# %%
path = '/content/gdrive/My Drive/Mask_Rcnn/'
start =160001 # -----------------------You should choose your numbers----------------------------------
black = np.zeros((224,224))



for i in range(1,101): #1 background image  -------------This is 1-100 == Same for all -------------

    bg = Image.open(f'{path}living_room_224_224/bg{str(i)}.jpg')

    for j in  range(21,41): #1 foreground image  ---------------You should choose your numbers. Place only 20 images no flipped one-------
     
      fg = Image.open(f'{path}Noopur/Foreground/fg{str(j)}.png')
      mask = Image.open(f'{path}Noopur/Foreground-Mask/mask{str(j)}.jpg').convert('1')

      for k in range(1,21): #---------------------Randomly Placing 20 times(Same for all)--------------------------------
       
        r1 = random.randint(1, 120)
        r2 = random.randint(1, 120)
        bg1 = copy.deepcopy(bg)
        bg2 = copy.deepcopy(bg)
        fg1 = copy.deepcopy(fg)
        m1 = copy.deepcopy(mask)
        black_img1 = Image.fromarray(black,mode='1')
        black_img2 = Image.fromarray(black,mode='1')

        flipfg = fg1.transpose(PIL.Image.FLIP_LEFT_RIGHT) #flip image
        flipmask = m1.transpose(PIL.Image.FLIP_LEFT_RIGHT) #flip mask

        

        bg1.paste(fg1, (r1,r2),fg1)
        bg2.paste(flipfg,(r1,r2),flipfg)
        black_img1.paste(m1,(r1,r2), m1)
        black_img2.paste(flipmask,(r1,r2), flipmask)
        bg1.save(f"/content/Overlay2/Fg-Bg/fg-bg{str(start)}.jpg",optimize=True, quality=30)#------------Create Different folder-------------
        black_img1.save(f"/content/Overlay2/Fg-Bg-Mask/fg-bg-mask{str(start)}.jpg",optimize=True, quality=30) #-------------Create Different Path folder----

        start+=1

        bg2.save(f"/content/Overlay2/Fg-Bg/fg-bg{str(start)}.jpg", optimize=True, quality=30)#------------Create Different folder---------------
        black_img2.save(f"/content/Overlay2/Fg-Bg-Mask/fg-bg-mask{str(start)}.jpg", optimize=True, quality=30)#------------Create Different folder-----------

        start+=1
        print(start)
# Out:
# Streaming output truncated to the last 5000 lines.
# 230005
# 230007
# 230009
# 230011
# 230013
# 230015
# 230017
# 230019
# 230021
# 230023
# 230025
# 230027
# 230029
# 230031
# 230033
# 230035
# 230037
# 230039
# 230041
# 230043
# 230045
# 230047
# 230049
# 230051
# 230053
# 230055
# 230057
# 230059
# 230061
# 230063
# 230065
# 230067
# 230069
# 230071
# 230073
# 230075
# 230077
# 230079
# 230081
# 230083
# 230085
# 230087
# 230089
# 230091
# 230093
# 230095
# 230097
# 230099
# 230101
# 230103
# 230105
# 230107
# 230109
# 230111
# 230113
# 230115
# 230117
# 230119
# 230121
# 230123
# 230125
# 230127
# 230129
# 230131
# 230133
# 230135
# 230137
# 230139
# 230141
# 230143
# 230145
# 230147
# 230149
# 230151
# 230153
# 230155
# 230157
# 230159
# 230161
# 230163
# 230165
# 230167
# 230169
# 230171
# 230173
# 230175
# 230177
# 230179
# 230181
# 230183
# 230185
# 230187
# 230189
# 230191
# 230193
# 230195
# 230197
# 230199
# 230201
# 230203
# 230205
# 230207
# 230209
# 230211
# 230213
# ...

# %%
# !zip -r /content/overlayed.zip /content/Overlay2

from google.colab import files
files.download("/content/overlayed2.zip")
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/Overlay2/Fg-Bg-Mask/fg-bg-mask226305.jpg (deflated 9%)
#   adding: content/Overlay2/Fg-Bg-Mask/fg-bg-mask224669.jpg (deflated 9%)
#   adding: content/Overlay2/Fg-Bg-Mask/fg-bg-mask218375.jpg (deflated 12%)
#   adding: content/Overlay2/Fg-Bg-Mask/fg-bg-mask202654.jpg (deflated 8%)
#   adding: content/Overlay2/Fg-Bg-Mask/fg-bg-mask230023.jpg (deflated 11%)
#   adding: content/Overlay2/Fg-Bg-Mask/fg-bg-mask216474.jpg (deflated 12%)
#   adding: content/Overlay2/Fg-Bg-Mask/fg-bg-mask173808.jpg (deflated 7%)
#   adding: content/Overlay2/Fg-Bg-Mask/fg-bg-mask199365.jpg (deflated 9%)
#   adding: content/Overlay2/Fg-Bg-Mask/fg-bg-mask213325.jpg (deflated 11%)
#   adding: content/Overlay2/Fg-Bg-Mask/fg-bg-mask193122.jpg (deflated 10%)
#   adding: content/Overlay2/Fg-Bg-Mask/fg-bg-mask186988.jpg (deflated 11%)
#   adding: content/Overlay2/Fg-Bg-Mask/fg-bg-mask209705.jpg (deflated 8%)
# ...

# %%
#files.download("/content/overlayed.zip")

# %%
# !pwd
# Out:
# /content

# %%
#Export Zip file
from zipfile import ZipFile 
import os 
  
def get_all_file_paths(directory): 
  
    # initializing empty file paths list 
    file_paths = [] 
  
    # crawling through directory and subdirectories 
    for root, directories, files in os.walk(directory): 
        for filename in files: 
            # join the two strings in order to form the full filepath. 
            filepath = os.path.join(root, filename) 
            file_paths.append(filepath) 
  
    # returning all file paths 
    return file_paths         
  
def main(): 
    # path to folder which needs to be zipped 
    directory = 'Overlay2'
  
    # calling function to get all file paths in the directory 
    file_paths = get_all_file_paths(directory) 
  
    # printing the list of all files to be zipped 
    print('Following files will be zipped:') 
    for file_name in file_paths:
        print(file_name) 
  
    # writing files to a zipfile 
    with ZipFile('/content/gdrive/My Drive/Mask_Rcnn/Noopur/test.zip','w') as zip: 
        # writing each file one by one 
        for file in file_paths: 
            zip.write(file) 
  
    print('All files zipped successfully!')         
  
  

main()
# Out:
# Streaming output truncated to the last 5000 lines.
# Overlay2/Fg-Bg-Mask/fg-bg-mask224669.jpg
# Overlay2/Fg-Bg-Mask/fg-bg-mask218375.jpg
# Overlay2/Fg-Bg-Mask/fg-bg-mask202654.jpg
# Overlay2/Fg-Bg-Mask/fg-bg-mask230023.jpg
# Overlay2/Fg-Bg-Mask/fg-bg-mask216474.jpg
# Overlay2/Fg-Bg-Mask/fg-bg-mask173808.jpg
# Overlay2/Fg-Bg-Mask/fg-bg-mask199365.jpg
# Overlay2/Fg-Bg-Mask/fg-bg-mask213325.jpg
# Overlay2/Fg-Bg-Mask/fg-bg-mask193122.jpg
# Overlay2/Fg-Bg-Mask/fg-bg-mask186988.jpg
# Overlay2/Fg-Bg-Mask/fg-bg-mask209705.jpg
# Overlay2/Fg-Bg-Mask/fg-bg-mask207390.jpg
# Overlay2/Fg-Bg-Mask/fg-bg-mask205838.jpg
# Overlay2/Fg-Bg-Mask/fg-bg-mask239929.jpg
# Overlay2/Fg-Bg-Mask/fg-bg-mask171241.jpg
# Overlay2/Fg-Bg-Mask/fg-bg-mask229231.jpg
# Overlay2/Fg-Bg-Mask/fg-bg-mask170209.jpg
# Overlay2/Fg-Bg-Mask/fg-bg-mask160212.jpg
# Overlay2/Fg-Bg-Mask/fg-bg-mask237737.jpg
# Overlay2/Fg-Bg-Mask/fg-bg-mask167750.jpg
# Overlay2/Fg-Bg-Mask/fg-bg-mask222371.jpg
# Overlay2/Fg-Bg-Mask/fg-bg-mask222437.jpg
# ...

# %%
# !ls
# Out:
# gdrive	Overlay2  overlayed.zip  sample_data

# %%
# !ls Overlay2/Fg-Bg | wc -l
# Out:
# 80000

# %%
# !ls Overlay2/Fg-Bg-Mask | wc -l
# Out:
# 80000
