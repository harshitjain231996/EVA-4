# %% [markdown]
# # 1st Method - Using Turtle

# %%
import turtle

# %%
from turtle import *

# %%
left(120)
forward(130)
left(120)
forward(130)
right(120)
forward(130)
left(120)
forward(130)
right(120)
forward(130)
left(120)
forward(130)

# %% [markdown]
# # 2nd Method - Using Matplotlib

# %%
import matplotlib.pyplot as plt
point1 = [1,2]
point2 = [3,4]
point3 = [5,2]
point4 = [7,4]
point5 = [9,2]
point6 = [11,4]
point7 = [13,2]
x_val = [point1[0],point2[0],point3[0],point4[0],point5[0],point6[0],point7[0]]
y_val = [point1[1],point2[1],point3[1],point4[1],point5[1],point6[1],point7[1]]
plt.plot(x_val,y_val)
plt.show()
